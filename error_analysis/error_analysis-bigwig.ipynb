# %%
from overlaps import (
    read_overlaps_from_file, merge_multiple_predictions, compute_crispr_overlaps
)
from misclassifications import get_misclassifications, label_misclassifications, LABELERS, groupby_gene
from main import OVERLAP_FILENAME
from df_loader import CrisprDFLoader, PredDFLoader
from schema import DFSchema
import pandas as pd
pd.set_option('display.max_rows', 100)

# %%
CRISPR_FILENAME = "/oak/stanford/groups/engreitz/Projects/Benchmarking/CRISPR_data/EPCrisprBenchmark_ensemble_data_GRCh38.tsv.gz"
PRED_FILENAME = "/oak/stanford/groups/engreitz/Users/atan5133/abc_run_comparisons/ABC-Enhancer-Gene-Prediction/results/K562_dhs_bw/Predictions/EnhancerPredictionsAllPutative.tsv.gz"
# OVERLAP_FILENAME = "crispr_pred_overlaps_noqnorm.csv"
THRESHOLD = 0.016
TSS_REF_FILE = "resources/genome_annotations/RefSeqCurated.170308.bed.CollapsedGeneBounds.hg38.TSS500bp.bed"

# %%
# overlaps = read_overlaps_from_file(OVERLAP_FILENAME)
pred_df = PredDFLoader(PRED_FILENAME, TSS_REF_FILE, THRESHOLD, "powerlaw.Score").load()
crispr_df = CrisprDFLoader(CRISPR_FILENAME, TSS_REF_FILE).load()
overlap_df = compute_crispr_overlaps(
    crispr_df, pred_df
)
overlaps = merge_multiple_predictions(overlap_df, THRESHOLD, "powerlaw.Score")
# Out:
# /oak/stanford/groups/engreitz/Users/atan5133/.conda/envs/error_analysis/lib/python3.9/site-packages/bioframe/core/specs.py:150: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   pd.api.types.is_categorical_dtype(chrom_dtype),
# /oak/stanford/groups/engreitz/Users/atan5133/.conda/envs/error_analysis/lib/python3.9/site-packages/bioframe/core/specs.py:150: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   pd.api.types.is_categorical_dtype(chrom_dtype),
# /oak/stanford/groups/engreitz/Users/atan5133/.conda/envs/error_analysis/lib/python3.9/site-packages/bioframe/ops.py:514: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df_input_2[overlap_df_idxs[:, 1] == -1] = None

# %%
misclass_df = get_misclassifications(overlaps)
label_misclassifications(misclass_df)
pd.set_option('display.max_rows', 100)

# %%
overlap_df[['chrom_pred', 'start_pred','end_pred', 'name_pred', 'distance_pred', 'normalized_dhs_pred', 'activity_base_pred', 'IsSignificant_crispr', 'IsSignificant_pred', 'powerlaw.Score_pred']].iloc[:20]
# Out:
#    chrom_pred  start_pred  end_pred                          name_pred  \
# 0        chr1     3774743   3775877         genic|chr1:3774743-3775877
# 1        chr1     3774743   3775877         genic|chr1:3774743-3775877
# 2        chr1     3803896   3804664    intergenic|chr1:3803896-3804664
# 3        chr1     3804903   3805717    intergenic|chr1:3804903-3805717
# 4        chr1     3774743   3775877         genic|chr1:3774743-3775877
# 5        chr1     3803896   3804664    intergenic|chr1:3803896-3804664
# 6        chr1     3804903   3805717    intergenic|chr1:3804903-3805717
# 7        None        <NA>      <NA>                               None
# 8        chr1     5304582   5305082    intergenic|chr1:5304582-5305082
# 9        chr1     8197384   8198250    intergenic|chr1:8197384-8198250
# 10       chr1     8899846   8900346    intergenic|chr1:8899846-8900346
# 11       chr1     8858068   8858568    intergenic|chr1:8858068-8858568
# 12       chr1     9145197   9145697    intergenic|chr1:9145197-9145697
# 13       chr1    10387693  10388480  intergenic|chr1:10387693-10388480
# 14       chr1    11881899  11882399  intergenic|chr1:11881899-11882399
# 15       chr1    11882724  11883673  intergenic|chr1:11882724-11883673
# 16       chr1    12014167  12015410  intergenic|chr1:12014167-12015410
# 17       chr1    11882724  11883673  intergenic|chr1:11882724-11883673
# 18       chr1    11882724  11883673  intergenic|chr1:11882724-11883673
# 19       chr1    12014167  12015410  intergenic|chr1:12014167-12015410
#
#     distance_pred  normalized_dhs_pred  activity_base_pred  \
# 0         81923.0             0.702383            0.702383
# 1         21194.0             0.702383            0.702383
# 2          7776.0             6.917205            6.917205
# 3          8806.0             0.641606            0.641606
# 4          2524.0             0.702383            0.702383
# 5         31494.0             6.917205            6.917205
# 6         32524.0             0.641606            0.641606
# 7             NaN                  NaN                 NaN
# 8        894787.0             2.694299            2.694299
# 9        236164.0             0.693438            0.693438
# 10       938443.0             7.225449            7.225449
# 11        20774.0             8.281593            8.281593
# 12       266355.0             1.617266            1.617266
# 13        84469.5             1.563938            1.563938
# 14       200935.0             7.232541            7.232541
# 15       201984.5             0.700745            0.700745
# 16       333574.5             0.657626            0.657626
# 17       147114.5             0.700745            0.700745
# 18       870577.5             0.700745            0.700745
# 19       954754.5             0.657626            0.657626
#
#     IsSignificant_crispr  IsSignificant_pred  powerlaw.Score_pred
# 0                   True               False             0.000469
# 1                   True               False             0.001595
# 2                  False                True             0.043864
# 3                  False               False             0.003582
# 4                   True               False             0.009310
# 5                  False               False             0.013924
# 6                  False               False             0.001250
# 7                  False               False                  NaN
# 8                  False               False             0.000127
# 9                  False               False             0.000301
# 10                 False               False             0.000764
# 11                  True                True             0.030660
# 12                 False               False             0.000439
# 13                 False               False             0.002984
# 14                 False               False             0.003378
# 15                 False               False             0.000326
# 16                 False               False             0.000183
# 17                 False               False             0.000213
# 18                 False               False             0.000138
# 19                 False               False             0.000073

# %%
overlap_df.columns
# Out:
# Index(['dataset_crispr', 'chrom_crispr', 'start_crispr', 'end_crispr',
#        'name_crispr', 'EffectSize_crispr', 'chrTSS_crispr',
#        'TargetGeneTSS_crispr', 'endTSS_crispr', 'TargetGene_crispr',
#        'IsSignificant_crispr', 'pValueAdjusted_crispr',
#        'PowerAtEffectSize25_crispr', 'ValidConnection_crispr',
#        'CellType_crispr', 'Reference_crispr', 'Regulated_crispr',
#        'PowerAtEffectSize10_crispr', 'PowerAtEffectSize15_crispr',
#        'PowerAtEffectSize20_crispr', 'PowerAtEffectSize50_crispr',
#        'pair_uid_crispr', 'merged_uid_crispr', 'merged_start_crispr',
#        'merged_end_crispr', 'DistanceToTSS_crispr', 'chrom_pred', 'start_pred',
#        'end_pred', 'name_pred', 'class_pred', 'activity_base_pred',
#        'normalized_dhs_pred', 'activity_base_squared_pred',
#        'enh_midpoint_pred', 'enh_idx_pred', 'TargetGene_pred',
#        'TargetGeneTSS_pred', 'TargetGeneExpression_pred',
#        'TargetGenePromoterActivityQuantile_pred', 'TargetGeneIsExpressed_pred',
#        'TargetGeneEnsembl_ID_pred', 'normalized_dhs_b_pred', 'gene_idx_pred',
#        'distance_pred', 'isSelfPromoter_pred', 'powerlaw_contact_pred',
#        'powerlaw_contact_reference_pred', 'powerlaw.Score.Numerator_pred',
#        'powerlaw.Score_pred', 'CellType_pred', 'DistanceToTSS_pred',
#        'IsSignificant_pred'],
#       dtype='object')

# %%
for labeler in LABELERS:
    print(labeler.summarize_category_count(misclass_df))
    print()
# Out:
# FalsePos_Category
# True    450
# Name: count, dtype: int64
#
# FalseNeg_Category
# True    332
# Name: count, dtype: int64
#
# DistToTSSSize_Category
# medium (<= 100000 bp)    422
# large (> 100000 bp)      249
# small (<= 10000 bp)      111
# Name: count, dtype: int64
#
# Top5Gene_Category
# MYC      14
# PLP2     13
# HDAC6    11
# PQBP1    10
# PRDX2    10
# Name: count, dtype: int64
#
# from_mult_pred
# True    42
# Name: count, dtype: int64
#
# EnhancerSize_Category
# Large     457
# Normal    325
# Name: count, dtype: int64

# %%
false_pos = len(misclass_df[(misclass_df["EnhancerSize_Category"] == "Large") & (misclass_df["FalsePos_Category"] == True)])
false_neg = len(misclass_df[(misclass_df["EnhancerSize_Category"] == "Large") & (misclass_df["FalseNeg_Category"] == True)])
print(f"False pos large enhancers: {false_pos}\nFalse neg large enhancers: {false_neg}")
# Out:
# False pos large enhancers: 304
# False neg large enhancers: 114

# %%
gata_1 = overlap_df[overlap_df[DFSchema.TARGET_GENE + DFSchema.CRISPR_SUFFIX] == "GATA1"]
gata_1 = gata_1.sort_values(by="activity_base_pred", ascending=False)
gata_1[["activity_base_pred", "hic_contact_pl_scaled_adj_pred", "ABC.Score_pred", "Regulated_crispr"]][:50]
# Out:
#       activity_base_pred  hic_contact_pl_scaled_adj_pred  ABC.Score_pred  \
# 9927           65.643916                        0.006329        0.009888
# 9937           52.973323                        0.002940        0.003706
# 9895           40.108691                        0.027504        0.026253
# 9894           40.108691                        0.027504        0.026253
# 9873           37.374110                        0.038451        0.034201
# 9874           37.374110                        0.038451        0.034201
# 9867           31.472263                        0.010772        0.008068
# 9793           28.581401                        0.000192        0.000130
# 9896           24.908039                        0.013216        0.007834
# 9831           24.068452                        0.005631        0.003226
# 9830           24.068452                        0.005631        0.003226
# 9897           23.988520                        0.013213        0.007543
# 9885           21.992132                        0.087190        0.045634
# 9925           21.852335                        0.003450        0.001794
# 9899           20.839893                        0.015799        0.007836
# 9810           18.261238                        0.000213        0.000093
# 9941           18.198574                        0.004490        0.001945
# 9882           17.206699                        0.248492        0.101757
# 9907           17.145826                        0.010710        0.004370
# 9768           16.954254                        0.000125        0.000051
# 9900           14.880984                        0.020099        0.007118
# 9912           14.648234                        0.014768        0.005148
# 9901           14.614217                        0.020104        0.006992
# 9777           13.664765                        0.000142        0.000046
# 9862           13.296704                        0.028000        0.008860
# 9863           13.296704                        0.028000        0.008860
# 9929           13.004652                        0.008256        0.002555
# 9813           12.300399                        0.001741        0.000510
# 9809           11.458208                        0.004202        0.001146
# 9790           10.863878                        0.001976        0.000511
# 9931           10.814024                        0.006720        0.001729
# 9806           10.528442                        0.000209        0.000052
# 9921            9.938199                        0.003994        0.000945
# 9834            9.802178                        0.004176        0.000974
# 9846            9.579245                        0.002467        0.000562
# 9845            9.579245                        0.002467        0.000562
# 9844            9.579245                        0.002467        0.000562
# 9823            9.299149                        0.000277        0.000061
# 9951            9.179496                        0.008954        0.001956
# 9976            9.008628                        0.000166        0.000036
# 9933            8.861782                        0.003546        0.000748
# 9847            8.245869                        0.002743        0.000538
# 9950            7.919042                        0.000476        0.000090
# 9945            7.555429                        0.004041        0.000727
# 9946            7.555429                        0.004041        0.000727
# 9791            6.958395                        0.000189        0.000031
# 9796            6.894018                        0.002828        0.000464
# 9819            6.691188                        0.000243        0.000039
# 9868            6.480260                        0.016110        0.002485
# 9934            6.469725                        0.003545        0.000546
#
#      Regulated_crispr
# 9927            False
# 9937            False
# 9895            False
# 9894            False
# 9873            False
# 9874            False
# 9867            False
# 9793            False
# 9896            False
# 9831            False
# 9830            False
# 9897            False
# 9885             True
# 9925            False
# 9899            False
# 9810            False
# 9941            False
# 9882             True
# 9907            False
# 9768            False
# 9900            False
# 9912            False
# 9901            False
# 9777            False
# 9862            False
# 9863            False
# 9929            False
# 9813            False
# 9809            False
# 9790            False
# 9931            False
# 9806            False
# 9921            False
# 9834            False
# 9846            False
# 9845            False
# 9844            False
# 9823            False
# 9951            False
# 9976            False
# 9933            False
# 9847            False
# 9950            False
# 9945            False
# 9946            False
# 9791            False
# 9796            False
# 9819            False
# 9868            False
# 9934            False

# %%
# Look at GATA1 classification
def print_target_gene_misclassification(target_gene):
    incorrect = len(misclass_df[misclass_df[DFSchema.TARGET_GENE + DFSchema.CRISPR_SUFFIX] == target_gene])
    total_pairs = len(overlaps[overlaps[DFSchema.TARGET_GENE + DFSchema.CRISPR_SUFFIX] == target_gene])
    print(f"Misclassified {incorrect}/{total_pairs} eg pairs for {target_gene}.\n{int(100 * incorrect/total_pairs)}% incorrect")

print_target_gene_misclassification("GATA1")
print_target_gene_misclassification("PLP2")
# Out:
# Misclassified 6/212 eg pairs for GATA1.
# 2% incorrect
# Misclassified 9/211 eg pairs for PLP2.
# 4% incorrect

# %%
# Example queries
print(misclass_df["FalsePos_Category"].value_counts().filter([True]))
print()
print(len(misclass_df.query("FalseNeg_Category == True")))
# Out:
# FalsePos_Category
# True    263
# Name: count, dtype: int64
#
# 211

# %%
sizes = pred_df["end"] - pred_df["start"]
num_normal = (sizes == 500).sum()
num_large = (sizes > 500).sum()

# %%
num_normal
# Out:
# 7083290

# %%
num_large
# Out:
# 1662088
